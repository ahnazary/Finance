# %%
import yahooquery
import pandas as pd

# %%
# print quarterly balance sheet of Apple
ticker = yahooquery.Ticker('AAPL')
ticker.balance_sheet(frequency='quarterly')
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# AAPL   2021-09-30         3M          USD     5.476300e+10
# AAPL   2021-12-31         3M          USD     7.436200e+10
# AAPL   2022-03-31         3M          USD     5.268200e+10
# AAPL   2022-06-30         3M          USD     4.834300e+10
# AAPL   2022-09-30         3M          USD     6.411500e+10
#
#         AccountsReceivable  AccumulatedDepreciation  \
# symbol
# AAPL          2.627800e+10            -7.028300e+10
# AAPL          3.021300e+10            -6.845400e+10
# AAPL          2.081500e+10            -7.002000e+10
# AAPL          2.180300e+10            -7.151600e+10
# AAPL          2.818400e+10            -7.234000e+10
#
#         AvailableForSaleSecurities  CapitalStock  CashAndCashEquivalents  \
# symbol
# AAPL                  1.278770e+11  5.736500e+10            3.494000e+10
# AAPL                  1.386830e+11  5.842400e+10            3.711900e+10
# ...

# %%
ticker.cash_flow()

# %%
# read an excel file into a pandas dataframe
df = pd.read_excel('data/Yahoo Ticker Symbols - September 2017.xlsx')
df
# Out:
#         Ticker                                     Name Exchange  \
# 0         OEDV  Osage Exploration and Development, Inc.      PNK
# 1         AAPL                               Apple Inc.      NMS
# 2          BAC              Bank of America Corporation      NYQ
# 3         AMZN                         Amazon.com, Inc.      NMS
# 4            T                                AT&T Inc.      NYQ
# ...        ...                                      ...      ...
# 106323  G5N.SG          Groupon Inc. Reg. Shares DL-,00      STU
# 106324  N1H.AX                      N1 Holdings Limited      ASX
# 106325  1K2.BE                  K2M GROUP HLDGS DL-,001      BER
# 106326  2RM.BE                 RE/MAX HLDGS A DL -,0001      BER
# 106327   2RM.F                    RE/MAX Holdings, Inc.      FRA
#
#                       Category Name    Country
# 0                               NaN        USA
# 1              Electronic Equipment        USA
# ...

# %%
# drop rows that the Country is not USA
df = df[df['Country'] == 'USA'].reset_index(drop=True)
df
# Out:
#       Ticker                                     Name Exchange  \
# 0       OEDV  Osage Exploration and Development, Inc.      PNK
# 1       AAPL                               Apple Inc.      NMS
# 2        BAC              Bank of America Corporation      NYQ
# 3       AMZN                         Amazon.com, Inc.      NMS
# 4          T                                AT&T Inc.      NYQ
# ...      ...                                      ...      ...
# 22164   USWL                   US-Worldlink.Com, Inc.      PNK
# 22165   GROG                         GroGenesis, Inc.      PNK
# 22166   INCT                            InCapta, Inc.      PNK
# 22167  INDVF                   IndigoVision Group plc      PNK
# 22168  INTQF                            InternetQ PLC      PNK
#
#                      Category Name Country
# 0                              NaN     USA
# 1             Electronic Equipment     USA
# 2               Money Center Banks     USA
# ...

# %%
""" result = pd.DataFrame()

for company in df["Ticker"]:
    try:
        ticker = yahooquery.Ticker(company)
        df = ticker.balance_sheet(frequency='quarterly')
        result["company"] = company
        
    except:
        pass """
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 # get revenue of ticker
#       2 ticker = yahooquery.Ticker('AAPL')
# ----> 3 ticker.revenue_estimate()
#       5 """ result = pd.DataFrame()
#       6
#       7 for company in df["Ticker"]:
#    (...)
#      13     except:
#      14         pass """
#
# AttributeError: 'Ticker' object has no attribute 'revenue_estimate'
